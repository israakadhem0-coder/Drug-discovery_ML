# %% [markdown]
# <a href="https://colab.research.google.com/github/israakadhem0-coder/Drug-discovery_ML/blob/main/python/CDD_ML_Part_1_bioactivity_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Computational Drug Discovery [Part 1] Download Bioactivity Data**

# %% [markdown]
# ## **ChEMBL Database**
#
# The [*ChEMBL Database*](https://www.ebi.ac.uk/chembl/) is a database that contains curated bioactivity data of more than 2 million compounds. It is compiled from more than 76,000 documents, 1.2 million assays and the data spans 13,000 targets and 1,800 cells and 33,000 indications.
# [Data as of March 25, 2020; ChEMBL version 26].

# %% [markdown]
# ## **Installing libraries**

# %% [markdown]
# Install the ChEMBL web service package so that we can retrieve bioactivity data from the ChEMBL Database.

# %%
! pip install chembl_webresource_client
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.2/55.2 kB 883.0 kB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.8/70.8 kB 3.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.1/73.1 kB 4.5 MB/s eta 0:00:00
# ...

# %% [markdown]
# ## **Importing libraries**

# %%
# Import necessary libraries
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %% [markdown]
# ## **Search for Target protein**

# %% [markdown]
# ### **Target search for NRF2**

# %%
# Target search for NRF2
target = new_client.target
target_query = target.search('NRF2')
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
#    cross_references           organism  \
# 0                []       Homo sapiens
# 1                []  Rattus norvegicus
# 2                []       Homo sapiens
# 3                []       Mus musculus
# 4                []       Homo sapiens
# 5                []       Mus musculus
# 6                []  Rattus norvegicus
# 7                []  Rattus norvegicus
# 8                []       Mus musculus
# 9                []       Homo sapiens
# 10               []       Mus musculus
# 11               []       Homo sapiens
# 12               []       Homo sapiens
# 13               []       Homo sapiens
# 14               []       Homo sapiens
# 15               []       Homo sapiens
#
#                                             pref_name  score  \
# 0                                          Keap1/Nrf2   17.0
# 1                                          KEAP1/NRF2   17.0
# 2                                           NRF2-MAFG   17.0
# ...

# %% [markdown]
# ### **Select and retrieve bioactivity data for NRF2**

# %%
selected_target = targets.target_chembl_id[4]
selected_target
# Out:
# 'CHEMBL1075094'

# %%
activity = new_client.activity
res = activity.filter(target_chembl_id=selected_target).filter(standard_type="IC50")

# %%
df = pd.DataFrame.from_dict(res)

# %%
df.head(3)
# Out:
#   action_type activity_comment  activity_id activity_properties  \
# 0        None             None     19259356                  []
# 1        None             None     19259357                  []
# 2        None             None     19453585                  []
#
#   assay_chembl_id                                  assay_description  \
# 0   CHEMBL4403711                Inhibition of Nrf2 (unknown origin)
# 1   CHEMBL4403711                Inhibition of Nrf2 (unknown origin)
# 2   CHEMBL4434437  Inhibition of NRF2 in human MDA-MB-231 cells h...
#
#   assay_type assay_variant_accession assay_variant_mutation bao_endpoint  ...  \
# 0          B                    None                   None  BAO_0000190  ...
# 1          B                    None                   None  BAO_0000190  ...
# 2          B                    None                   None  BAO_0000190  ...
#
#   target_organism                             target_pref_name target_tax_id  \
# ...

# %%
df.standard_type.unique()
# Out:
# array(['IC50'], dtype=object)

# %% [markdown]
# Finally we will save the resulting bioactivity data to a CSV file **bioactivity_data.csv**.

# %%
df.to_csv('bioactivity_data.csv', index=False)

# %% [markdown]
# ## **Copying files to Google Drive**

# %% [markdown]
# Firstly, we need to mount the Google Drive into Colab so that we can have access to our Google adrive from within Colab.

# %%
from google.colab import drive
drive.mount('/content/gdrive/', force_remount=True)
# Out:
# Mounted at /content/gdrive/

# %% [markdown]
# Next, we create a **data** folder in our **Colab Notebooks** folder on Google Drive.

# %%
! mkdir "/content/gdrive/My Drive/Colab Notebooks/TAHA"
# Out:
# mkdir: cannot create directory ‘/content/gdrive/My Drive/Colab Notebooks/TAHA’: File exists

# %%
! cp bioactivity_data.csv "/content/gdrive/My Drive/Colab Notebooks/TAHA"

# %%
! ls -l "/content/gdrive/My Drive/Colab Notebooks/TAHA"
# Out:
# total 6
# -rw------- 1 root root 5247 Aug 25 18:22 bioactivity_data.csv

# %% [markdown]
# Let's see the CSV files that we have so far.

# %%
! ls
# Out:
# bioactivity_data.csv  gdrive  sample_data

# %% [markdown]
# Taking a glimpse of the **bioactivity_data.csv** file that we've just created.

# %%
! head bioactivity_data.csv
# Out:
# action_type,activity_comment,activity_id,activity_properties,assay_chembl_id,assay_description,assay_type,assay_variant_accession,assay_variant_mutation,bao_endpoint,bao_format,bao_label,canonical_smiles,data_validity_comment,data_validity_description,document_chembl_id,document_journal,document_year,ligand_efficiency,modality,molecule_chembl_id,molecule_pref_name,parent_molecule_chembl_id,pchembl_value,potential_duplicate,qudt_units,record_id,relation,src_id,standard_flag,standard_relation,standard_text_value,standard_type,standard_units,standard_upper_value,standard_value,target_chembl_id,target_organism,target_pref_name,target_tax_id,text_value,toid,type,units,uo_units,upper_value,value
# ...

# %% [markdown]
# ## **Handling missing data**
# If any compounds has missing value for the **standard_value** column then drop it

# %%
df2 = df[df.standard_value.notna()]
df2
# Out:
#                                          action_type activity_comment  \
# 0                                               None             None
# 1                                               None             None
# 2                                               None             None
# 3  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 4  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 5  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 6  {'action_type': 'INHIBITOR', 'description': 'N...             None
#
#    activity_id activity_properties assay_chembl_id  \
# 0     19259356                  []   CHEMBL4403711
# 1     19259357                  []   CHEMBL4403711
# 2     19453585                  []   CHEMBL4434437
# 3     26129625                  []   CHEMBL5617281
# 4     26129626                  []   CHEMBL5617281
# 5     26129639                  []   CHEMBL5617293
# ...

# %% [markdown]
# Apparently, for this dataset there is no missing data. But we can use the above code cell for bioactivity data of other target protein.

# %% [markdown]
# ## **Data pre-processing of the bioactivity data**

# %% [markdown]
# ### **Labeling compounds as either being active, inactive or intermediate**
# The bioactivity data is in the IC50 unit. Compounds having values of less than 1000 nM will be considered to be **active** while those greater than 10,000 nM will be considered to be **inactive**. As for those values in between 1,000 and 10,000 nM will be referred to as **intermediate**.

# %%
bioactivity_class = []
for i in df2.standard_value:
  if float(i) >= 10000:
    bioactivity_class.append("inactive")
  elif float(i) <= 1000:
    bioactivity_class.append("active")
  else:
    bioactivity_class.append("intermediate")

# %% [markdown]
# ### **Iterate the *molecule_chembl_id* to a list**

# %%
mol_cid = []
for i in df2.molecule_chembl_id:
  mol_cid.append(i)

# %% [markdown]
# ### **Iterate *canonical_smiles* to a list**

# %%
canonical_smiles = []
for i in df2.canonical_smiles:
  canonical_smiles.append(i)

# %% [markdown]
# ### **Iterate *standard_value* to a list**

# %%
standard_value = []
for i in df2.standard_value:
  standard_value.append(i)

# %% [markdown]
# ### **Combine the 4 lists into a dataframe**

# %%
data_tuples = list(zip(mol_cid, canonical_smiles, bioactivity_class, standard_value))
df3 = pd.DataFrame( data_tuples,  columns=['molecule_chembl_id', 'canonical_smiles', 'bioactivity_class', 'standard_value'])

# %%
df3
# Out:
#   molecule_chembl_id                                   canonical_smiles  \
# 0      CHEMBL3617787  CC(=O)N[C@@H](CC(=O)O)C(=O)N[C@@H](CCC(=O)O)C(...
# 1      CHEMBL3928693  CC(=O)N[C@@H](CC(=O)O)C(=O)N1CCC[C@H]1C(=O)N[C...
# 2       CHEMBL459546  COC(=O)[C@@]12OC[C@]34[C@H]([C@@H](O)[C@@H]1O)...
# 3      CHEMBL5288795           Cc1cc(C)cc(Nc2nc(C)c(-c3ccccc3)cc2C#N)c1
# 4      CHEMBL5619019                             Nc1ccc(OCCC2CCCCC2)cc1
# 5      CHEMBL1197091           O=C(CC1NCCCC1O)Cn1cnc2cc(Br)c(Cl)cc2c1=O
# 6      CHEMBL1197091           O=C(CC1NCCCC1O)Cn1cnc2cc(Br)c(Cl)cc2c1=O
#
#   bioactivity_class standard_value
# 0      intermediate         5390.0
# 1            active          115.0
# 2            active          29.19
# 3      intermediate         5000.0
# 4      intermediate         2900.0
# 5            active           22.3
# 6            active           37.2

# %% [markdown]
# ### **Alternative method**

# %%
selection = ['molecule_chembl_id', 'canonical_smiles', 'standard_value']
df3 = df2[selection]
df3
# Out:
#   molecule_chembl_id                                   canonical_smiles  \
# 0      CHEMBL3617787  CC(=O)N[C@@H](CC(=O)O)C(=O)N[C@@H](CCC(=O)O)C(...
# 1      CHEMBL3928693  CC(=O)N[C@@H](CC(=O)O)C(=O)N1CCC[C@H]1C(=O)N[C...
# 2       CHEMBL459546  COC(=O)[C@@]12OC[C@]34[C@H]([C@@H](O)[C@@H]1O)...
# 3      CHEMBL5288795           Cc1cc(C)cc(Nc2nc(C)c(-c3ccccc3)cc2C#N)c1
# 4      CHEMBL5619019                             Nc1ccc(OCCC2CCCCC2)cc1
# 5      CHEMBL1197091           O=C(CC1NCCCC1O)Cn1cnc2cc(Br)c(Cl)cc2c1=O
# 6      CHEMBL1197091           O=C(CC1NCCCC1O)Cn1cnc2cc(Br)c(Cl)cc2c1=O
#
#   standard_value
# 0         5390.0
# 1          115.0
# 2          29.19
# 3         5000.0
# 4         2900.0
# 5           22.3
# 6           37.2

# %%
pd.concat([df3,pd.Series(bioactivity_class)], axis=1)
# Out:
#   molecule_chembl_id                                   canonical_smiles  \
# 0      CHEMBL3617787  CC(=O)N[C@@H](CC(=O)O)C(=O)N[C@@H](CCC(=O)O)C(...
# 1      CHEMBL3928693  CC(=O)N[C@@H](CC(=O)O)C(=O)N1CCC[C@H]1C(=O)N[C...
# 2       CHEMBL459546  COC(=O)[C@@]12OC[C@]34[C@H]([C@@H](O)[C@@H]1O)...
# 3      CHEMBL5288795           Cc1cc(C)cc(Nc2nc(C)c(-c3ccccc3)cc2C#N)c1
# 4      CHEMBL5619019                             Nc1ccc(OCCC2CCCCC2)cc1
# 5      CHEMBL1197091           O=C(CC1NCCCC1O)Cn1cnc2cc(Br)c(Cl)cc2c1=O
# 6      CHEMBL1197091           O=C(CC1NCCCC1O)Cn1cnc2cc(Br)c(Cl)cc2c1=O
#
#   standard_value             0
# 0         5390.0  intermediate
# 1          115.0        active
# 2          29.19        active
# 3         5000.0  intermediate
# 4         2900.0  intermediate
# 5           22.3        active
# 6           37.2        active

# %% [markdown]
# Saves dataframe to CSV file

# %%
df3.to_csv('bioactivity_preprocessed_data.csv', index=False)

# %%
! ls -l
# Out:
# total 20
# -rw-r--r-- 1 root root 5247 Aug 25 18:22 bioactivity_data.csv
# -rw-r--r-- 1 root root  743 Aug 25 18:23 bioactivity_preprocessed_data.csv
# drwx------ 5 root root 4096 Aug 25 18:22 gdrive
# drwxr-xr-x 1 root root 4096 Aug 24 13:21 sample_data

# %% [markdown]
# Let's copy to the Google Drive

# %%
! cp bioactivity_preprocessed_data.csv "/content/gdrive/My Drive/Colab Notebooks/TAHA"

# %%
! ls "/content/gdrive/My Drive/Colab Notebooks/TAHA"
# Out:
# bioactivity_data.csv  bioactivity_preprocessed_data.csv

# %% [markdown]
# ---
